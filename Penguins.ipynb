# %% [markdown]
# Penguins

# %% [markdown]
# # **Loading the Penguin dataset to Python**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/penguins.csv"
df = pd.read_csv(url)

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
df.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %% [markdown]
# There is existence of ouliers in the dataset since maximum number is greater than mean.

# %%
df.describe(include=np.object_)
# Out:
#        species  island   sex
# count      344     344   333
# unique       3       3     2
# top     Adelie  Biscoe  MALE
# freq       152     168   168

# %% [markdown]
# # **Quick insights**
# The mode for this dataset is Adelie species. This means Adelie species is the common species in the entire dataset and male are dominat. It is noted Biscoe island is dominated by Adelie species.

# %%
sns.kdeplot(data=df, x="flipper_length_mm", hue="species", multiple="stack")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Density'>

# %% [markdown]
# # **Penguins species in a scatter plot : Flipper Length vs Bill Length**

# %%
f, axs = plt.subplots(1, 2, figsize=(8, 4), gridspec_kw=dict(width_ratios=[4, 3]))
sns.scatterplot(data=df, x="flipper_length_mm", y="bill_length_mm", hue="species", ax=axs[0])
sns.histplot(data=df, x="species", hue="species", shrink=.6, alpha=.8, legend=False, ax=axs[1])
# Out:
# <Axes: xlabel='species', ylabel='Count'>

# %% [markdown]
# Per island

# %%
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='bill_length_mm'>

# %%
g=sns.jointplot(data=df, x="flipper_length_mm", y="bill_length_mm", kind="scatter")
g.plot_joint(sns.kdeplot)

# %% [markdown]
# Gentoo species penguins are dominant mostly in Biscoe Island, while Adelie species is common in Torgersen Island. Chinstrap is dominant in Dream island.
# From the above, it is noted Gentoo species have both long flipper and bill.

# %%
g = sns.FacetGrid(df, col="sex")
g.map(plt.scatter, "flipper_length_mm", "bill_length_mm")

# %%
sns.pairplot(df, vars=["flipper_length_mm", "bill_length_mm"], palette="husl", kind="scatter", hue="species")

# %%
sns.pairplot(df, vars=["flipper_length_mm", "bill_length_mm"], palette="husl", kind="scatter", hue="sex")

# %%
sns.regplot(data=df, x="flipper_length_mm", y="bill_length_mm", order=2, marker="^")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='bill_length_mm'>

# %%
sns.violinplot(data=df, x="flipper_length_mm", y="bill_length_mm", palette="husl")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='bill_length_mm'>

# %%
sns.boxenplot(data=df, x="flipper_length_mm", y="bill_length_mm", palette="husl")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='bill_length_mm'>
